# %%
import pandas as pd

# %%
#sales data
sales = pd.read_csv('Data/Sales_Data - Sheet1.csv')
sales.head(10)
# Out:
#    transaction_id  item_id  unit_sale_price date_of_transaction  \
# 0               1        6           5.6465             09/2019
# 1               2        5           3.6110             10/2019
# 2               3        1           6.7850             11/2019
# 3               4        2           4.8300             09/2019
# 4               5        6           5.6465             12/2019
# 5               6        1           6.7850             10/2019
# 6               7        5           3.6110             12/2019
# 7               8        6           5.6465             10/2019
# 8               9        7          13.1675             12/2019
# 9              10       10           6.6240             10/2019
#
#    currency_value_of_transaction  \
# 0                        28.2325
# 1                        10.8330
# 2                        27.1400
# 3                        28.9800
# 4                        11.2930
# 5                        27.1400
# ...

# %%
#client data
client = pd.read_csv('Data/Client_data - Sheet1.csv')
client.head(10)
# Out:
#    client_id client_description client_type
# 0          1       Amerigo West  Individual
# 1          2          Macrosoft   Corporate
# 2          3   Vladimir Molotov  Individual
# 3          4    Charles LeClerc   Corporate
# 4          5       Cheesy Cakes   Corporate

# %%
#inventory data
inv = pd.read_csv('Data/Inventory_Stock_Levels - Sheet1.csv')
inv.head(10)
# Out:
#    Item_id              item_description  item_price(last_purchase_price)  \
# 0        1               Bacon 500 grams                             5.90
# 1        2              Butter 454 grams                             4.20
# 2        3      Beef stewing cuts per KG                            14.52
# 3        4  Beef top sirloin cuts per KG                            12.11
# 4        5                Eggs per dozen                             3.14
# 5        6          Whole chicken per KG                             4.91
# 6        7        Chicken breasts per KG                            11.45
# 7        8          Chicken thigh per KG                             8.05
# 8        9               Tomatoes per KG                             3.29
# 9       10                Peppers per KG                             5.76
#
#    quantity_in_stock  set_minimum last_restocking_date
# 0                 50            5          August 2019
# ...

# %%
#Seasonal Sales Patterns
amount_sold_monthly =
